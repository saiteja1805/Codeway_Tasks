# %% [markdown]
# <a href="https://colab.research.google.com/github/saiteja1805/Codeway_Tasks/blob/main/TASK_2_CREDIT_CARD_FRAUD_DETECTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("/content/drive/MyDrive/codeway_datasets/fraudTest.csv")
dataset.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# ...

# %%
dataset.tail()
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                      merchant        category     amt    first     last  \
# 555714  fraud_Reilly and Sons  health_fitness   43.77  Michael    Olson
# 555715   fraud_Hoppe-Parisian       kids_pets  111.84     Jose  Vasquez
# 555716        fraud_Rau-Robel       kids_pets   86.88      Ann   Lawson
# 555717  fraud_Breitenberg LLC          travel    7.99     Eric  Preston
# 555718      fraud_Dare-Marvin   entertainment   38.13   Samuel     Frey
#
#        gender                      street  ...      lat      long  city_pop  \
# 555714      M         558 Michael Estates  ...  40.4931  -91.8912       519
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             555719 non-null  int64
#  1   trans_date_trans_time  555719 non-null  object
#  2   cc_num                 555719 non-null  int64
#  3   merchant               555719 non-null  object
#  4   category               555719 non-null  object
#  5   amt                    555719 non-null  float64
#  6   first                  555719 non-null  object
#  7   last                   555719 non-null  object
#  8   gender                 555719 non-null  object
#  9   street                 555719 non-null  object
#  10  city                   555719 non-null  object
#  11  state                  555719 non-null  object
#  12  zip                    555719 non-null  int64
#  13  lat                    555719 non-null  float64
# ...

# %%
#checking number of missing values in each column
dataset.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
#distribution of legit transaction and fraudulant transaction
dataset['is_fraud'].value_counts()
# Out:
# 0    553574
# 1      2145
# Name: is_fraud, dtype: int64

# %% [markdown]
# this dataset is highly unbalanced

# %%
#seperating the data for analysis
is_legit = dataset[dataset.is_fraud==0]
is_fraud = dataset[dataset.is_fraud==1]
print(is_fraud.shape)
# Out:
# (2145, 23)

# %%
print(is_legit.shape)
# Out:
# (553574, 23)

# %%
#statistical measures of data
dataset.groupby('is_fraud').mean()
# Out:
# <ipython-input-47-5377b9521c51>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataset.groupby('is_fraud').mean()
#              Unnamed: 0        cc_num         amt           zip        lat  \
# is_fraud
# 0         277997.725990  4.179643e+17   67.614408  48846.424285  38.541406
# 1         242057.088112  3.854274e+17  528.356494  47862.900233  39.019971
#
#                long      city_pop     unix_time  merch_lat  merch_long
# is_fraud
# 0        -90.230495  88313.692365  1.380683e+09  38.540954  -90.230474
# 1        -90.445556  64529.321678  1.379587e+09  39.018618  -90.465222

# %%
new_dataset = pd.concat([is_legit,is_fraud],axis=0)
new_dataset.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
new_dataset.tail()
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 517197      517197   2020-12-22 22:05:48  2242176657877538
# 517274      517274   2020-12-22 22:18:07  2242176657877538
# 517341      517341   2020-12-22 22:31:48  2242176657877538
# 517529      517529   2020-12-22 23:06:03  2242176657877538
# 517571      517571   2020-12-22 23:13:39  2242176657877538
#
#                                    merchant      category      amt   first  \
# 517197      fraud_Willms, Kris and Bergnaum  shopping_pos  1041.51  Travis
# 517274                       fraud_Kuhn LLC  shopping_pos   868.09  Travis
# 517341  fraud_Mosciski, Ziemann and Farrell  shopping_net  1039.42  Travis
# 517529                   fraud_Bauch-Raynor   grocery_pos   289.27  Travis
# 517571           fraud_Jaskolski-Vandervort      misc_net   766.38  Travis
#
#           last gender                       street  ...      lat     long  \
# 517197  Daniel      M  1327 Rose Causeway Apt. 610  ...  34.6323 -89.8855
# ...

# %%
new_dataset['is_fraud'].value_counts()
# Out:
# 0    553574
# 1      2145
# Name: is_fraud, dtype: int64

# %%
new_dataset = new_dataset.drop(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'trans_num'], axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
categorical_columns = ['merchant', 'category', 'first', 'last', 'gender', 'street', 'city', 'state', 'job', 'dob']
for col in categorical_columns:
    new_dataset[col] = label_encoder.fit_transform(new_dataset[col])
new_dataset.head()
# Out:
#    merchant  category    amt  first  last  gender  street  city  state    zip  \
# 0       319        10   2.86    151   115       1     341   157     39  29209
# 1       591        10  29.84    163   457       0     354    16     43  84002
# 2       611         5  41.28     24   249       0     865    61     33  11710
# 3       222         9  60.05     42   457       1     320   764      8  32780
# 4       292        13   3.19    247   261       1     548   247     21  49632
#
#        lat      long  city_pop  job  dob   unix_time  merch_lat  merch_long  \
# 0  33.9659  -80.9355    333497  275  376  1371816865  33.986391  -81.200714
# 1  40.3207 -110.4360       302  392  760  1371816873  39.450498 -109.960431
# 2  40.6729  -73.5365     34496  259  421  1371816893  40.495810  -74.196111
# 3  28.5697  -80.8191     54767  407  718  1371816915  28.812398  -80.883061
# 4  44.2529  -85.0170      1126  196  177  1371816917  44.959148  -85.884734
#
#    is_fraud
# 0         0
# 1         0
# ...

# %%
x = new_dataset.drop(columns='is_fraud',axis=1)
y=new_dataset['is_fraud']

# %%
x
# Out:
#         merchant  category      amt  first  last  gender  street  city  state  \
# 0            319        10     2.86    151   115       1     341   157     39
# 1            591        10    29.84    163   457       0     354    16     43
# 2            611         5    41.28     24   249       0     865    61     33
# 3            222         9    60.05     42   457       1     320   764      8
# 4            292        13     3.19    247   261       1     548   247     21
# ...          ...       ...      ...    ...   ...     ...     ...   ...    ...
# 517197       670        12  1041.51    324    94       1     115   701     24
# 517274       349        12   868.09    324    94       1     115   701     24
# 517341       443        11  1039.42    324    94       1     115   701     24
# 517529        29         4   289.27    324    94       1     115   701     24
# 517571       281         8   766.38    324    94       1     115   701     24
#
# ...

# %%
new_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 555719 entries, 0 to 517571
# Data columns (total 19 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   merchant    555719 non-null  int64
#  1   category    555719 non-null  int64
#  2   amt         555719 non-null  float64
#  3   first       555719 non-null  int64
#  4   last        555719 non-null  int64
#  5   gender      555719 non-null  int64
#  6   street      555719 non-null  int64
#  7   city        555719 non-null  int64
#  8   state       555719 non-null  int64
#  9   zip         555719 non-null  int64
#  10  lat         555719 non-null  float64
#  11  long        555719 non-null  float64
#  12  city_pop    555719 non-null  int64
#  13  job         555719 non-null  int64
#  14  dob         555719 non-null  int64
#  15  unix_time   555719 non-null  int64
#  16  merch_lat   555719 non-null  float64
#  17  merch_long  555719 non-null  float64
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,stratify = y ,random_state=1)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((444575, 18), (111144, 18), (444575,), (111144,))

# %%
x_train.head()
# Out:
#         merchant  category    amt  first  last  gender  street  city  state  \
# 473964       349        12  18.12    316    35       0     419   706     48
# 317924       560         8  13.41    160   211       0      29    87      8
# 178147       645         4  98.94    150   189       1     207   327     47
# 355590       564        10   6.81    282   178       0     569   772     33
# 10102        381         2  40.12    247   266       1     462   693     13
#
#           zip      lat     long  city_pop  job  dob   unix_time  merch_lat  \
# 473964  25442  39.3716 -77.8229      1925  430  335  1386988309  39.908673
# 317924  33510  27.9551 -82.2966     79613  171  568  1382239978  28.107770
# 178147  54441  44.6437 -90.1031       828   37  793  1377232756  44.699682
# 355590  12986  44.2320 -74.4905      6120   65  536  1383692134  43.775011
# 10102   60193  42.0144 -88.0935     92294   81  394  1372038717  41.661821
#
#         merch_long
# 473964  -78.118527
# ...

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn.metrics import accuracy_score
x_pred = model.predict(x_train)
train_data_accuracy = accuracy_score(x_pred,y_train)

# %%
print("traing_data_accuracy : ",train_data_accuracy)
# Out:
# traing_data_accuracy :  0.9944148906258786

# %%
y_pred = model.predict(x_test)
test_data_accuracy = accuracy_score(y_pred,y_test)

# %%
print("testing_data_accuracy : ",test_data_accuracy)
# Out:
# testing_data_accuracy :  0.9939897790254085
